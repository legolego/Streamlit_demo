# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f /work/Streamlit_demo/For_github/streamlit/requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' /work/Streamlit_demo/For_github/streamlit/requirements.txt
#
#     #This line was added to get rid of the warning about pip
#     pip install --upgrade pip
#
#     pip install -r /work/Streamlit_demo/For_github/streamlit/requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Requirement already satisfied: pip in /root/venv/lib/python3.9/site-packages (23.1.2)
# Requirement already satisfied: streamlit==1.13.0 in /root/venv/lib/python3.9/site-packages (from -r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 1)) (1.13.0)
# Requirement already satisfied: altair in /shared-libs/python3.9/py/lib/python3.9/site-packages (from -r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 2)) (4.2.2)
# Requirement already satisfied: blinker>=1.0.0 in /root/venv/lib/python3.9/site-packages (from streamlit==1.13.0->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 1)) (1.6.2)
# Requirement already satisfied: cachetools>=4.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit==1.13.0->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 1)) (5.2.0)
# Requirement already satisfied: click>=7.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit==1.13.0->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 1)) (8.1.3)
# Requirement already satisfied: importlib-metadata>=1.4 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit==1.13.0->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 1)) (5.0.0)
# Requirement already satisfied: numpy in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit==1.13.0->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 1)) (1.23.4)
# Requirement already satisfied: packaging>=14.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from streamlit==1.13.0->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 1)) (21.3)
# Requirement already satisfied: pandas>=0.21.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit==1.13.0->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 1)) (1.2.5)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit==1.13.0->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 1)) (9.2.0)
# Requirement already satisfied: protobuf!=3.20.2,<4,>=3.12 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit==1.13.0->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 1)) (3.19.6)
# Requirement already satisfied: pyarrow>=4.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit==1.13.0->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 1)) (9.0.0)
# Requirement already satisfied: pydeck>=0.1.dev5 in /root/venv/lib/python3.9/site-packages (from streamlit==1.13.0->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 1)) (0.8.1b0)
# Requirement already satisfied: pympler>=0.9 in /root/venv/lib/python3.9/site-packages (from streamlit==1.13.0->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: python-dateutil in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from streamlit==1.13.0->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: requests>=2.4 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit==1.13.0->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 1)) (2.28.1)
# Requirement already satisfied: rich>=10.11.0 in /root/venv/lib/python3.9/site-packages (from streamlit==1.13.0->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 1)) (13.3.5)
# Requirement already satisfied: semver in /root/venv/lib/python3.9/site-packages (from streamlit==1.13.0->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: toml in /root/venv/lib/python3.9/site-packages (from streamlit==1.13.0->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 1)) (0.10.2)
# Requirement already satisfied: tornado>=5.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from streamlit==1.13.0->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 1)) (6.2)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit==1.13.0->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 1)) (4.4.0)
# Requirement already satisfied: tzlocal>=1.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit==1.13.0->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 1)) (4.2)
# Requirement already satisfied: validators>=0.2 in /root/venv/lib/python3.9/site-packages (from streamlit==1.13.0->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 1)) (0.20.0)
# Requirement already satisfied: gitpython!=3.1.19 in /root/venv/lib/python3.9/site-packages (from streamlit==1.13.0->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 1)) (3.1.31)
# Requirement already satisfied: watchdog in /root/venv/lib/python3.9/site-packages (from streamlit==1.13.0->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: entrypoints in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from altair->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 2)) (0.4)
# Requirement already satisfied: jinja2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from altair->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 2)) (2.11.3)
# Requirement already satisfied: jsonschema>=3.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from altair->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 2)) (3.2.0)
# Requirement already satisfied: toolz in /shared-libs/python3.9/py/lib/python3.9/site-packages (from altair->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 2)) (0.12.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /root/venv/lib/python3.9/site-packages (from gitpython!=3.1.19->streamlit==1.13.0->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 1)) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from importlib-metadata>=1.4->streamlit==1.13.0->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 1)) (3.9.0)
# Requirement already satisfied: attrs>=17.4.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jsonschema>=3.0->altair->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 2)) (22.1.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jsonschema>=3.0->altair->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 2)) (0.18.1)
# Requirement already satisfied: setuptools in /root/venv/lib/python3.9/site-packages (from jsonschema>=3.0->altair->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 2)) (58.1.0)
# Requirement already satisfied: six>=1.11.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jsonschema>=3.0->altair->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from packaging>=14.1->streamlit==1.13.0->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 1)) (3.0.9)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas>=0.21.0->streamlit==1.13.0->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 1)) (2022.5)
# Requirement already satisfied: MarkupSafe>=0.23 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jinja2->altair->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests>=2.4->streamlit==1.13.0->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 1)) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests>=2.4->streamlit==1.13.0->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 1)) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests>=2.4->streamlit==1.13.0->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 1)) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests>=2.4->streamlit==1.13.0->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 1)) (2022.9.24)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /root/venv/lib/python3.9/site-packages (from rich>=10.11.0->streamlit==1.13.0->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 1)) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from rich>=10.11.0->streamlit==1.13.0->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 1)) (2.13.0)
# Requirement already satisfied: pytz-deprecation-shim in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tzlocal>=1.1->streamlit==1.13.0->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 1)) (0.1.0.post0)
# Requirement already satisfied: decorator>=3.4.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from validators>=0.2->streamlit==1.13.0->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 1)) (5.1.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /root/venv/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit==1.13.0->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 1)) (5.0.0)
# Requirement already satisfied: mdurl~=0.1 in /root/venv/lib/python3.9/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->streamlit==1.13.0->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 1)) (0.1.2)
# Requirement already satisfied: tzdata in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pytz-deprecation-shim->tzlocal>=1.1->streamlit==1.13.0->-r /work/Streamlit_demo/For_github/streamlit/requirements.txt (line 1)) (2022.5)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=4329245f-fd25-472c-b2b7-a57f57a1a9f7' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
